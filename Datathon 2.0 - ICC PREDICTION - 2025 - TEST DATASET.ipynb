# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = "/mnt/data/Copy of Test Data_28 Feb 2025.xlsx"
df = pd.read_excel("/content/Copy of Test Data_28 Feb 2025.xlsx")

# Compute correlation matrix (only for numerical features)
correlation_matrix = df.corr(numeric_only=True)

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Team Performance Metrics")
plt.show()

# Return correlation matrix for review
correlation_matrix
# Out:
#                      Year  Matches Played  Matches Won  Avg Runs Per Match  \
# Year                  NaN             NaN          NaN                 NaN
# Matches Played        NaN        1.000000     0.555556           -0.017304
# Matches Won           NaN        0.555556     1.000000            0.120138
# Avg Runs Per Match    NaN       -0.017304     0.120138            1.000000
# Strike Rate           NaN        0.308515     0.048944           -0.419113
# Number of Centuries   NaN        0.084215     0.477219            0.433079
# Number of Fifties     NaN       -0.277350    -0.215717            0.069278
# Highest Team Total    NaN        0.018421    -0.118712           -0.456305
# Wickets Taken         NaN        0.223574     0.716582            0.291112
# Bowling Avg           NaN       -0.304694    -0.563965            0.535439
# Bowling Econ Rate     NaN       -0.074781    -0.654265           -0.177842
# Five-Wicket Hauls     NaN        0.333333     0.555556           -0.220318
# Catches Taken         NaN        0.173688     0.598259            0.307431
# Run Outs              NaN        0.397360     0.750568            0.700074
# Stumpings             NaN        0.397360    -0.397360           -0.226156
# maiden over           NaN       -0.333333     0.259259            0.492933
# NRR                   NaN        0.227136     0.613106           -0.102727
# total fours           NaN       -0.105230    -0.055121            0.517343
# total six             NaN       -0.259489    -0.338122           -0.090990
# Host Advantage        NaN       -0.218218    -0.363696            0.333965
#
#                      Strike Rate  Number of Centuries  Number of Fifties  \
# Year                         NaN                  NaN                NaN
# Matches Played          0.308515             0.084215          -0.277350
# Matches Won             0.048944             0.477219          -0.215717
# Avg Runs Per Match     -0.419113             0.433079           0.069278
# Strike Rate             1.000000             0.175939          -0.022598
# Number of Centuries     0.175939             1.000000          -0.490499
# Number of Fifties      -0.022598            -0.490499           1.000000
# Highest Team Total      0.876855             0.305609          -0.223094
# Wickets Taken          -0.066691             0.777754          -0.615312
# Bowling Avg            -0.599804            -0.447173           0.354445
# Bowling Econ Rate       0.349214            -0.176132          -0.342329
# Five-Wicket Hauls      -0.264805             0.084215          -0.647150
# Catches Taken          -0.082380             0.697229          -0.497782
# Run Outs               -0.306057             0.501956          -0.183680
# Stumpings               0.607897            -0.033464          -0.183680
# maiden over            -0.127381             0.701793           0.154083
# NRR                     0.463636             0.384126           0.294588
# total fours             0.066927             0.634266          -0.587883
# total six              -0.332908            -0.268195          -0.111225
# Host Advantage         -0.330042            -0.606450           0.544705
#
#                      Highest Team Total  Wickets Taken  Bowling Avg  \
# Year                                NaN            NaN          NaN
# Matches Played                 0.018421       0.223574    -0.304694
# Matches Won                   -0.118712       0.716582    -0.563965
# Avg Runs Per Match            -0.456305       0.291112     0.535439
# Strike Rate                    0.876855      -0.066691    -0.599804
# Number of Centuries            0.305609       0.777754    -0.447173
# Number of Fifties             -0.223094      -0.615312     0.354445
# Highest Team Total             1.000000       0.091556    -0.649361
# Wickets Taken                  0.091556       1.000000    -0.500850
# Bowling Avg                   -0.649361      -0.500850     1.000000
# Bowling Econ Rate              0.492695      -0.241907     0.183155
# Five-Wicket Hauls             -0.171928       0.636325    -0.362070
# Catches Taken                  0.132601       0.950889    -0.444103
# Run Outs                      -0.434303       0.703880     0.021105
# Stumpings                      0.524579      -0.389526    -0.075869
# maiden over                   -0.016374       0.372623    -0.147175
# NRR                            0.246365       0.174077    -0.617886
# total fours                    0.253658       0.511125     0.085150
# total six                      0.004780       0.105887     0.158422
# Host Advantage                -0.462273      -0.439090     0.786647
#
#                      Bowling Econ Rate  Five-Wicket Hauls  Catches Taken  \
# Year                               NaN                NaN            NaN
# Matches Played               -0.074781           0.333333       0.173688
# Matches Won                  -0.654265           0.555556       0.598259
# Avg Runs Per Match           -0.177842          -0.220318       0.307431
# Strike Rate                   0.349214          -0.264805      -0.082380
# Number of Centuries          -0.176132           0.084215       0.697229
# Number of Fifties            -0.342329          -0.647150      -0.497782
# Highest Team Total            0.492695          -0.171928       0.132601
# Wickets Taken                -0.241907           0.636325       0.950889
# Bowling Avg                   0.183155          -0.362070      -0.444103
# Bowling Econ Rate             1.000000          -0.103728      -0.179279
# Five-Wicket Hauls            -0.103728           1.000000       0.559662
# Catches Taken                -0.179279           0.559662       1.000000
# Run Outs                     -0.458503           0.397360       0.636487
# Stumpings                     0.589504          -0.397360      -0.375758
# maiden over                  -0.569567          -0.333333       0.366675
# NRR                          -0.654854          -0.190373       0.082053
# total fours                   0.502360           0.075165       0.469117
# total six                     0.357423           0.306669       0.342806
# Host Advantage                0.193190          -0.218218      -0.341117
#
#                      Run Outs  Stumpings  maiden over       NRR  total fours  \
# Year                      NaN        NaN          NaN       NaN          NaN
# Matches Played       0.397360   0.397360    -0.333333  0.227136    -0.105230
# Matches Won          0.750568  -0.397360     0.259259  0.613106    -0.055121
# Avg Runs Per Match   0.700074  -0.226156     0.492933 -0.102727     0.517343
# Strike Rate         -0.306057   0.607897    -0.127381  0.463636     0.066927
# Number of Centuries  0.501956  -0.033464     0.701793  0.384126     0.634266
# Number of Fifties   -0.183680  -0.183680     0.154083  0.294588    -0.587883
# Highest Team Total  -0.434303   0.524579    -0.016374  0.246365     0.253658
# Wickets Taken        0.703880  -0.389526     0.372623  0.174077     0.511125
# Bowling Avg          0.021105  -0.075869    -0.147175 -0.617886     0.085150
# Bowling Econ Rate   -0.458503   0.589504    -0.569567 -0.654854     0.502360
# Five-Wicket Hauls    0.397360  -0.397360    -0.333333 -0.190373     0.075165
# Catches Taken        0.636487  -0.375758     0.366675  0.082053     0.469117
# Run Outs             1.000000  -0.473684     0.309058  0.181755     0.340488
# Stumpings           -0.473684   1.000000    -0.309058 -0.068286     0.089602
# maiden over          0.309058  -0.309058     1.000000  0.528464     0.165362
# NRR                  0.181755  -0.068286     0.528464  1.000000    -0.337086
# total fours          0.340488   0.089602     0.165362 -0.337086     1.000000
# total six           -0.159352  -0.196847    -0.275215 -0.672602     0.079791
# Host Advantage       0.086711  -0.260133    -0.363696 -0.466236    -0.029524
#
#                      total six  Host Advantage
# Year                       NaN             NaN
# Matches Played       -0.259489       -0.218218
# Matches Won          -0.338122       -0.363696
# Avg Runs Per Match   -0.090990        0.333965
# Strike Rate          -0.332908       -0.330042
# Number of Centuries  -0.268195       -0.606450
# Number of Fifties    -0.111225        0.544705
# Highest Team Total    0.004780       -0.462273
# Wickets Taken         0.105887       -0.439090
# Bowling Avg           0.158422        0.786647
# Bowling Econ Rate     0.357423        0.193190
# Five-Wicket Hauls     0.306669       -0.218218
# Catches Taken         0.342806       -0.341117
# Run Outs             -0.159352        0.086711
# Stumpings            -0.196847       -0.260133
# maiden over          -0.275215       -0.363696
# NRR                  -0.672602       -0.466236
# total fours           0.079791       -0.029524
# total six             1.000000        0.262535
# Host Advantage        0.262535        1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the path of the cleaned dataset
file_path = "/content/cleaned_dataset.csv"  # Change this to your actual file path

# Load the cleaned dataset
df = pd.read_csv(file_path)
print(f"Cleaned dataset '{file_path}' loaded successfully.\n")

# Display basic information
print("\nBasic Information:")
print(df.info())

# Display summary statistics
print("\nSummary Statistics:")
print(df.describe())

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Check for duplicate rows
print("\nDuplicate Rows:", df.duplicated().sum())

# Check column-wise unique values
print("\nColumn-wise Unique Values:")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")

# Visualizing missing values
plt.figure(figsize=(10, 5))
sns.heatmap(df.isnull(), cmap='viridis', cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# Plot histograms for feature distributions
df.hist(figsize=(12, 10), bins=30, edgecolor='black')
plt.suptitle("Feature Distributions", fontsize=16)
plt.show()

# Correlation heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Cleaned dataset '/content/cleaned_dataset.csv' loaded successfully.
#
#
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 8 non-null      int64
#  1   Team                 8 non-null      int64
#  2   Group                8 non-null      int64
#  3   Matches Played       8 non-null      int64
#  4   Matches Won          8 non-null      int64
#  5   Avg Runs Per Match   8 non-null      float64
#  6   Strike Rate          8 non-null      float64
#  7   Team’s Top Scorer    8 non-null      int64
#  8   Number of Centuries  8 non-null      int64
#  9   Number of Fifties    8 non-null      int64
#  10  Highest Team Total   8 non-null      int64
#  11  Wickets Taken        8 non-null      int64
#  12  Top Wicket-Taker     8 non-null      int64
#  13  Bowling Avg          8 non-null      float64
#  14  Bowling Econ Rate    8 non-null      float64
#  15  Five-Wicket Hauls    8 non-null      int64
#  16  Catches Taken        8 non-null      int64
#  17  Run Outs             8 non-null      int64
#  18  Stumpings            8 non-null      int64
#  19  maiden over          8 non-null      int64
#  20  NRR                  8 non-null      float64
#  21  total fours          8 non-null      int64
#  22  total six            8 non-null      int64
#  23  Host Advantage       8 non-null      int64
# dtypes: float64(5), int64(19)
# memory usage: 1.6 KB
# None
#
# Summary Statistics:
#          Year     Team     Group  Matches Played  Matches Won  \
# count     8.0  8.00000  8.000000         8.00000      8.00000
# mean   2025.0  3.50000  0.500000         3.25000      1.25000
# std       0.0  2.44949  0.534522         0.46291      1.38873
# min    2025.0  0.00000  0.000000         3.00000      0.00000
# 25%    2025.0  1.75000  0.000000         3.00000      0.00000
# 50%    2025.0  3.50000  0.500000         3.00000      1.00000
# 75%    2025.0  5.25000  1.000000         3.25000      2.00000
# max    2025.0  7.00000  1.000000         4.00000      4.00000
#
#        Avg Runs Per Match  Strike Rate  Team’s Top Scorer  \
# count            8.000000     8.000000            8.00000
# mean           202.521250    94.180000            3.50000
# std             45.345161    14.544343            2.44949
# min            141.670000    72.620000            0.00000
# 25%            166.125000    85.315000            1.75000
# 50%            207.750000    91.660000            3.50000
# 75%            233.250000   105.520000            5.25000
# max            270.500000   116.580000            7.00000
#
#        Number of Centuries  Number of Fifties  ...  Bowling Econ Rate  \
# count             8.000000           8.000000  ...           8.000000
# mean              1.375000           1.875000  ...           5.611250
# std               0.916125           0.834523  ...           0.959486
# min               0.000000           1.000000  ...           4.370000
# 25%               1.000000           1.000000  ...           4.952500
# 50%               1.000000           2.000000  ...           5.565000
# 75%               2.000000           2.250000  ...           6.292500
# max               3.000000           3.000000  ...           7.070000
#
#        Five-Wicket Hauls  Catches Taken  Run Outs  Stumpings  maiden over  \
# count            8.00000       8.000000  8.000000   8.000000      8.00000
# mean             0.25000       7.375000  0.750000   0.750000      1.25000
# std              0.46291       3.997767  1.164965   1.164965      1.38873
# min              0.00000       4.000000  0.000000   0.000000      0.00000
# 25%              0.00000       4.000000  0.000000   0.000000      0.00000
# 50%              0.00000       5.500000  0.000000   0.000000      1.00000
# 75%              0.25000      11.000000  1.250000   1.250000      2.00000
# max              1.00000      14.000000  3.000000   3.000000      4.00000
#
#             NRR  total fours  total six  Host Advantage
# count  8.000000     8.000000   8.000000        8.000000
# mean   0.162500    40.750000   8.875000        0.125000
# std    1.082873    10.264363   3.270539        0.353553
# min   -1.087000    25.000000   5.000000        0.000000
# 25%   -0.579750    34.500000   6.000000        0.000000
# 50%    0.085000    40.500000   9.000000        0.000000
# 75%    0.701000    45.250000  10.250000        0.000000
# max    2.140000    57.000000  15.000000        1.000000
#
# [8 rows x 24 columns]
#
# Missing Values:
# Year                   0
# Team                   0
# Group                  0
# Matches Played         0
# Matches Won            0
# Avg Runs Per Match     0
# Strike Rate            0
# Team’s Top Scorer      0
# Number of Centuries    0
# Number of Fifties      0
# Highest Team Total     0
# Wickets Taken          0
# Top Wicket-Taker       0
# Bowling Avg            0
# Bowling Econ Rate      0
# Five-Wicket Hauls      0
# Catches Taken          0
# Run Outs               0
# Stumpings              0
# maiden over            0
# NRR                    0
# total fours            0
# total six              0
# Host Advantage         0
# dtype: int64
#
# Duplicate Rows: 0
#
# Column-wise Unique Values:
# Year: 1 unique values
# Team: 8 unique values
# Group: 2 unique values
# Matches Played: 2 unique values
# Matches Won: 4 unique values
# Avg Runs Per Match: 8 unique values
# Strike Rate: 8 unique values
# Team’s Top Scorer: 8 unique values
# Number of Centuries: 4 unique values
# Number of Fifties: 3 unique values
# Highest Team Total: 8 unique values
# Wickets Taken: 6 unique values
# Top Wicket-Taker: 8 unique values
# Bowling Avg: 8 unique values
# Bowling Econ Rate: 7 unique values
# Five-Wicket Hauls: 2 unique values
# Catches Taken: 5 unique values
# Run Outs: 4 unique values
# Stumpings: 4 unique values
# maiden over: 4 unique values
# NRR: 8 unique values
# total fours: 8 unique values
# total six: 6 unique values
# Host Advantage: 2 unique values

# %%
import pandas as pd

# Create a DataFrame with past ICC Champions Trophy winners
historical_winners = pd.DataFrame({
    "Year": [1998, 2000, 2002, 2004, 2006, 2009, 2013, 2017],
    "Winner": ["South Africa", "New Zealand", "India/Sri Lanka", "West Indies",
               "Australia", "Australia", "India", "Pakistan"]
})

# Save to CSV (optional)
historical_winners.to_csv("/content/historical_winners.csv", index=False)
print("Historical winners dataset created!")
# Out:
# Historical winners dataset created!

# %%
# Load your cleaned dataset
cleaned_dataset = pd.read_csv("/content/cleaned_dataset.csv")

# Ensure your cleaned dataset has a 'Year' column to match tournaments
if "Year" not in cleaned_dataset.columns:
    print("Your dataset must contain a 'Year' column to merge historical data!")

# Merge cleaned data with historical winners
merged_df = cleaned_dataset.merge(historical_winners, on="Year", how="left")

# Save the merged dataset for model training
merged_df.to_csv("/content/merged_dataset.csv", index=False)
print("Merged dataset saved successfully!")
# Out:
# Merged dataset saved successfully!

# %%
print(merged_df.head())  # View sample rows
print(merged_df["Winner"].value_counts())  # Check winner distribution
# Out:
#    Year  Team  Group  Matches Played  Matches Won  Avg Runs Per Match  \
# 0  2025     5      0               3            2              270.50
# 1  2025     4      0               4            4              231.00
# 2  2025     2      0               3            0              214.00
# 3  2025     6      0               3            0              240.00
# 4  2025     0      1               3            1              141.67
#
#    Strike Rate  Team’s Top Scorer  Number of Centuries  Number of Fifties  \
# 0        93.76                  7                    3                  2
# 1        86.32                  6                    2                  1
# 2        72.62                  3                    1                  2
# 3        82.30                  5                    0                  3
# 4        89.56                  1                    1                  1
#
#    ...  Run Outs  Stumpings  maiden over    NRR  total fours  total six  \
# 0  ...         2          0            4  0.863           52         10
# 1  ...         3          0            1  0.647           43          6
# 2  ...         0          1            2 -0.443           33          9
# 3  ...         1          0            0 -1.087           40         11
# 4  ...         0          0            0 -0.990           41         15
#
#    Host Advantage  Outcome  Outcome.1  Winner
# 0               0      NaN        NaN     NaN
# 1               0      NaN        NaN     NaN
# 2               0      NaN        NaN     NaN
# 3               1      NaN        NaN     NaN
# 4               0      NaN        NaN     NaN
#
# [5 rows x 27 columns]
# Series([], Name: count, dtype: int64)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Step 1: Load the Cleaned Dataset
file_path = "/content/cleaned_dataset.csv"  # Update with actual file path
df = pd.read_csv(file_path)

# Step 2: Drop Non-Numeric Columns (If Any)
df_numeric = df.select_dtypes(include=[np.number])  # Keep only numeric columns

# Step 3: Apply Feature Scaling (Standardization)
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_numeric), columns=df_numeric.columns)

# Step 4: Compute VIF for Each Feature
vif_data = pd.DataFrame()
vif_data["Feature"] = df_scaled.columns
vif_data["VIF"] = [variance_inflation_factor(df_scaled.values, i) for i in range(df_scaled.shape[1])]

# Step 5: Display VIF Results
print("\n📊 Variance Inflation Factor (VIF) Analysis 📊")
print(vif_data.sort_values(by="VIF", ascending=False))

# Step 6: Visualize Feature Correlation Matrix
plt.figure(figsize=(10, 6))
sns.heatmap(df_scaled.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1784: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# 📊 Variance Inflation Factor (VIF) Analysis 📊
#                 Feature  VIF
# 1                  Team  inf
# 13          Bowling Avg  inf
# 22            total six  inf
# 21          total fours  inf
# 20                  NRR  inf
# 19          maiden over  inf
# 18            Stumpings  inf
# 17             Run Outs  inf
# 16        Catches Taken  inf
# 15    Five-Wicket Hauls  inf
# 14    Bowling Econ Rate  inf
# 12     Top Wicket-Taker  inf
# 2                 Group  inf
# 11        Wickets Taken  inf
# 10   Highest Team Total  inf
# 9     Number of Fifties  inf
# 8   Number of Centuries  inf
# 7     Team’s Top Scorer  inf
# 6           Strike Rate  inf
# 5    Avg Runs Per Match  inf
# 4           Matches Won  inf
# 3        Matches Played  inf
# 23       Host Advantage  inf
# 0                  Year  NaN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Step 1: Load the Cleaned Dataset (Without Outcome Column)
file_path = "/content/cleaned_dataset.csv"  # Update with actual path
df = pd.read_csv(file_path)

# Step 2: Select Only Numeric Columns (Ensure No Categorical Variables)
df_numeric = df.select_dtypes(include=[np.number])

# Step 3: Apply Feature Scaling (Standardization)
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_numeric), columns=df_numeric.columns)

# Step 4: Apply PCA to Identify Feature Contribution
pca = PCA(n_components=2)  # Using 2 components for analysis
df_pca = pca.fit_transform(df_scaled)

# Step 5: Train a Random Forest Regressor to Compute Feature Importance
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(df_scaled, np.random.rand(df_scaled.shape[0]))  # Random target for unsupervised importance

# Step 6: Extract Feature Importances
feature_importance = pd.DataFrame({'Feature': df_numeric.columns, 'Importance': model.feature_importances_})
feature_importance = feature_importance.sort_values(by="Importance", ascending=False)

# Step 7: Plot Feature Importance
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance["Importance"], y=feature_importance["Feature"], palette="viridis")
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("Top Contributing Features (Unsupervised)")
plt.show()

# Step 8: Print the Top Features
print("\n📊 Top Contributing Features 📊")
print(feature_importance.head(10))  # Display top 10 important features
# Out:
# <ipython-input-73-1fc1aabbf75b>:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_importance["Importance"], y=feature_importance["Feature"], palette="viridis")
# 📊 Top Contributing Features 📊
#                 Feature  Importance
# 5    Avg Runs Per Match    0.216390
# 1                  Team    0.099076
# 13          Bowling Avg    0.088966
# 22            total six    0.085427
# 7     Team’s Top Scorer    0.068695
# 8   Number of Centuries    0.051479
# 20                  NRR    0.049807
# 17             Run Outs    0.047034
# 9     Number of Fifties    0.044054
# 14    Bowling Econ Rate    0.035697

# %%
import pandas as pd
import numpy as np

# Load the dataset
file_path = "/mnt/data/Copy of Test Data_28 Feb 2025.xlsx"
df = pd.read_excel("/content/Copy of Test Data_28 Feb 2025.xlsx")

# Display the first few rows to understand the structure
df.head()
# Out:
#    Year         Team Group  Matches Played  Matches Won  Avg Runs Per Match  \
# 0  2025  New zealand     A               3            2              270.50
# 1  2025        India     A               4            4              231.00
# 2  2025   Bangladesh     A               3            0              214.00
# 3  2025     Pakistan     A               3            0              240.00
# 4  2025  Afganisthan     B               3            1              141.67
#
#    Strike Rate Team’s Top Scorer  Number of Centuries  Number of Fifties  ...  \
# 0        93.76        tom latham                    3                  2  ...
# 1        86.32      Shubman Gill                    2                  1  ...
# 2        72.62         Jaker ali                    1                  2  ...
# 3        82.30              Shah                    0                  3  ...
# 4        89.56   Ibrahim Zadran                     1                  1  ...
#
#    Bowling Econ Rate  Five-Wicket Hauls Catches Taken  Run Outs  Stumpings  \
# 0               5.06                  0            14         2          0
# 1               4.63                  1            11         3          0
# 2               5.06                  0             4         0          1
# 3               6.07                  0             4         1          0
# 4               6.27                  1            11         0          0
#
#    maiden over    NRR  total fours  total six  Host Advantage
# 0            4  0.863           52         10               0
# 1            1  0.647           43          6               0
# 2            2 -0.443           33          9               0
# 3            0 -1.087           40         11               1
# 4            0 -0.990           41         15               0
#
# [5 rows x 24 columns]

# %%
# Monte Carlo Simulation for ICC Champions Trophy Prediction

# Define number of simulations
num_simulations = 10000

# Extract relevant features for probability estimation
teams = df["Team"].values
matches_won = df["Matches Won"].values
net_run_rate = df["NRR"].values

# Normalize probabilities (higher weight to matches won and NRR)
win_probabilities = (matches_won + (net_run_rate + abs(net_run_rate.min()) + 1)) / sum(matches_won + (net_run_rate + abs(net_run_rate.min()) + 1))

# Simulate tournaments
simulation_results = np.random.choice(teams, size=num_simulations, p=win_probabilities)

# Count how many times each team wins
team_win_counts = pd.Series(simulation_results).value_counts(normalize=True) * 100  # Convert to percentage

# Display results
team_win_counts.sort_values(ascending=False)
# Out:
# India           23.66
# South Africa    21.55
# New zealand     18.19
# Australia       13.01
# Afganisthan      8.01
# England          6.13
# Bangladesh       5.93
# Pakistan         3.52
# Name: proportion, dtype: float64
